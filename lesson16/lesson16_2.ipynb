# %% [markdown]
# https://www.perplexity.ai/search/8906abee-eea5-4924-8e07-f2f2029af740

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])

type(score_pd.index)

score_pd.columns.name = '科目'
score_pd.index.name = '學號'

sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series

# %%
sorted_pd = score_pd.sort_values(by='總分',ascending=False)
rand_series = sorted_pd['總分'].rank(ascending=False,method='min')
sorted_pd['名次'] = rand_series

# %%
sorted_pd
# Out:
# 科目    國文  英文   數學   地理   歷史   總分    平均    名次
# 學號
# 學生42  89  99  100   75   87  450  90.0   1.0
# 學生20  91  98   86   89   86  450  90.0   1.0
# 學生9   93  98   90   69   80  430  86.0   3.0
# 學生37  99  86   88   67   88  428  85.6   4.0
# 學生4   83  99   65   86   94  427  85.4   5.0
# 學生43  62  73   89   88  100  412  82.4   6.0
# 學生5   83  81   94   73   78  409  81.8   7.0
# 學生2   75  95   95   91   53  409  81.8   7.0
# 學生13  77  89   92   59   92  409  81.8   7.0
# 學生32  99  57   90   94   67  407  81.4  10.0
# 學生34  83  97   56   95   76  407  81.4  10.0
# 學生15  85  75   85   62   99  406  81.2  12.0
# 學生6   81  71   67   96   88  403  80.6  13.0
# 學生44  92  75   95   85   54  401  80.2  14.0
# 學生49  99  53   82   80   86  400  80.0  15.0
# 學生18  50  80   81   89   98  398  79.6  16.0
# 學生16  93  87   53  100   63  396  79.2  17.0
# 學生46  65  57   94   91   89  396  79.2  17.0
# 學生17  78  65   88   80   82  393  78.6  19.0
# 學生40  89  71   83   84   63  390  78.0  20.0
# 學生45  80  68   83   60   99  390  78.0  20.0
# 學生19  73  98   96   72   51  390  78.0  20.0
# 學生25  76  74   98   77   65  390  78.0  20.0
# 學生22  91  96   58   75   65  385  77.0  24.0
# 學生21  69  86   65   97   66  383  76.6  25.0
# 學生1   90  51   95   72   75  383  76.6  25.0
# 學生10  84  86   76   62   68  376  75.2  27.0
# 學生24  82  77   55   79   82  375  75.0  28.0
# 學生36  91  95   61   62   65  374  74.8  29.0
# 學生27  85  82   60   53   94  374  74.8  29.0
# 學生31  85  79   54   65   90  373  74.6  31.0
# 學生29  97  58   64   56   95  370  74.0  32.0
# 學生41  65  84   59   60  100  368  73.6  33.0
# 學生50  70  68   79   93   57  367  73.4  34.0
# 學生35  52  50   90   84   90  366  73.2  35.0
# 學生12  85  54   66   74   86  365  73.0  36.0
# 學生47  96  52   59   72   84  363  72.6  37.0
# 學生33  76  85   65   58   79  363  72.6  37.0
# 學生38  59  78   78   80   66  361  72.2  39.0
# 學生14  83  76   53   60   87  359  71.8  40.0
# 學生7   62  51   80   89   72  354  70.8  41.0
# 學生26  71  51   71   62   97  352  70.4  42.0
# 學生48  89  55   84   65   55  348  69.6  43.0
# 學生23  83  56   56   58   84  337  67.4  44.0
# 學生3   64  76   54   77   65  336  67.2  45.0
# 學生28  56  94   71   57   56  334  66.8  46.0
# 學生8   78  50   65   73   65  331  66.2  47.0
# 學生11  53  58   67   76   75  329  65.8  48.0
# 學生39  64  85   50   54   70  323  64.6  49.0
# 學生30  67  60   67   65   51  310  62.0  50.0
