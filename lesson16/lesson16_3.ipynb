# %% [markdown]
# https://www.perplexity.ai/search/9037605f-7d32-4bed-887a-66ffe09265ab

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
score_pd.to_excel('3年7班.xlsx',index=True)

# %%
import os
script = os.path.realpath(__name__)
script_root = os.path.dirname(script)
excel_folder = os.path.join(script_root,"excel")
os.listdir(excel_folder)
for excel_name in os.listdir(excel_folder):
    print(excel_name)
# Out:
# 3年5班.xlsx
# 3年6班.xlsx
# 3年7班.xlsx

# %%
import os
import pandas as pd

def rank(filepath:str):
    df = pd.read_excel(filepath,index_col='學號')
    display(df)

script_path = os.path.realpath(__name__)
script_root = os.path.dirname(script_path)
excel_folder = os.path.join(script_root,"excel")

for excel_name in os.listdir(excel_folder):
    excel_path = os.path.join(excel_folder,excel_name)
    rank(excel_path)
# Out:
#       國文   英文  數學   地理  歷史
# 學號
# 學生1   57   89  76   61  66
# 學生2   83   69  87   61  94
# 學生3   74   66  90  100  85
# 學生4   94   90  92  100  66
# 學生5   83   82  61   56  81
# 學生6   84   93  57  100  83
# 學生7   60   96  95   63  98
# 學生8   80   84  65   84  94
# 學生9   91   81  51   67  79
# 學生10  71   93  80   70  54
# 學生11  71   89  84   99  76
# 學生12  82   81  53   93  67
# 學生13  77   97  77   77  50
# 學生14  91   91  78   60  55
# 學生15  66   95  70   88  99
# 學生16  83   94  65   71  66
# 學生17  91   68  80   68  54
# 學生18  69   75  82   86  50
# 學生19  85   86  89   90  72
# 學生20  78   83  63   78  95
# 學生21  97   88  97   74  85
# 學生22  61   53  64   72  80
# 學生23  74   95  54   77  92
# 學生24  80   67  52   63  94
# 學生25  89   91  50   84  81
# 學生26  66   54  90   93  94
# 學生27  56   62  62   53  80
# 學生28  70   93  87   86  74
# 學生29  63   58  85   81  83
# 學生30  83   68  63   57  54
# 學生31  71   62  74   71  55
# 學生32  65   82  68   50  70
# 學生33  87   74  88   75  81
# 學生34  92   63  77   72  51
# 學生35  60  100  67   99  96
# 學生36  51   54  91   85  57
# 學生37  60   86  53   81  59
# 學生38  70   60  55   77  61
# 學生39  73   99  50   61  77
# 學生40  82   81  95   84  66
# 學生41  75   70  61   93  57
# 學生42  56   87  64   84  67
# 學生43  97   91  83   75  68
# 學生44  56   93  68   75  95
# 學生45  70   74  65   73  66
# 學生46  92   51  80   84  56
# 學生47  75   68  76   97  64
# 學生48  53   87  85   64  75
# 學生49  80   96  67   59  88
# 學生50  74   80  85   80  50
#        國文  英文   數學  地理   歷史
# 學號
# 學生1    66  98   79  54   61
# 學生2    89  77   91  59   90
# 學生3    82  64   98  83   75
# 學生4    87  99   57  97   65
# 學生5    93  84   95  89   66
# 學生6    96  74   59  51   89
# 學生7    88  53   91  77   53
# 學生8    81  91   62  91   87
# 學生9    76  84   68  56   81
# 學生10   80  92   74  52   56
# 學生11   80  79   95  62   61
# 學生12   75  92   77  83   99
# 學生13   58  82   59  63  100
# 學生14  100  95   73  91   70
# 學生15   89  84   74  68   67
# 學生16   91  90   98  60   82
# 學生17   83  68   95  81   97
# 學生18   60  75   82  99   73
# 學生19   88  97   80  79   62
# 學生20   59  60   72  53   53
# 學生21   91  91   75  85   74
# 學生22   60  78   51  51   60
# 學生23   63  70   78  58   51
# 學生24   62  63   53  73   94
# 學生25   59  53   58  58   81
# 學生26   79  54   77  54   90
# 學生27   82  60   85  69   57
# 學生28   80  82   74  63   64
# 學生29   86  88   53  72   51
# 學生30   89  62   71  66  100
# 學生31   52  87   71  69   84
# 學生32   61  76   72  95   60
# 學生33   87  53   68  62   65
# 學生34   65  51  100  81   51
# 學生35   50  72   64  72   69
# 學生36   95  61   97  58   57
# 學生37   65  98   53  63   97
# 學生38   84  61   96  96   98
# 學生39   56  51   74  79   65
# 學生40   58  89   65  54   50
# 學生41   95  51   69  51   64
# 學生42   53  78   90  86   50
# 學生43   91  94   95  70   59
# 學生44   67  95   90  71   57
# 學生45   54  79  100  82   86
# 學生46  100  70   81  77   61
# 學生47   77  59   66  75  100
# 學生48   66  78   69  90   94
# 學生49   82  55   54  87   97
# 學生50   76  65   92  88   87
#        國文   英文   數學   地理   歷史
# 學號
# 學生1    58   86   54   89   72
# 學生2    78   78   57   55   69
# 學生3    91   70   70   65   73
# 學生4    82   90   92   68   89
# 學生5    80   95   70  100  100
# 學生6    77   78   69   57   68
# 學生7    66   99   61   65   92
# 學生8    96   93   78   94   87
# 學生9   100   69   78   76   91
# 學生10  100   66   93   96   71
# 學生11   54   76   81   52   82
# 學生12   88   52   64   50   78
# 學生13   57   53   66   95   62
# 學生14   83   84   92   81   84
# 學生15   59   52   57   80   66
# 學生16   93   76   69   87   54
# 學生17   87   90   65   75   76
# 學生18   58   86   91   65   94
# 學生19   76   95   84   81   88
# 學生20   54   54   80   73   60
# 學生21  100   84   73   84   62
# 學生22   87  100   65   60   59
# 學生23   97   61   91   73   57
# 學生24   66   51   63   92   98
# 學生25   93   80   54   99   78
# 學生26   53   74   70   73   85
# 學生27   62   99   89   97   50
# 學生28   70   72   96   73   51
# 學生29   91   90   56   87   86
# 學生30   81   90   92   96   75
# 學生31   92   72   78   88   96
# 學生32   53   64   86   60   98
# 學生33   99   68   60   69   52
# 學生34   75   85   83   57   62
# 學生35   82   78   70   88   75
# 學生36   99   71   51   81   82
# 學生37   72   60  100   55   89
# 學生38   80   60   88   99   52
# 學生39   57   82   96   54   95
# 學生40   89   86   95   82   88
# 學生41   84   90   59   96   58
# 學生42   60   51   73   74   93
# 學生43   58   76   56   57   63
# 學生44   82   96   90   76   97
# 學生45   83   77   77   99   61
# 學生46   53   54   98   90   68
# 學生47   75   94   51   50   77
# 學生48   89   86   78   68   97
# 學生49   78   54   52   56   78
# 學生50   86   63   84   55   61
