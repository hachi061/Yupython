# %% [markdown]
# https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc

# %% [markdown]
# ### jinja2套件

# %%
#Styler.format()
#Style.format_index()
#Style.relabel_index()

import pandas as pd
import numpy as np 

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
type(df.style)
display(df)

s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])
s
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230
# <style type="text/css">
# </style>
# <table id="T_30f2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30f2d_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_30f2d_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_30f2d_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30f2d_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_30f2d_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_30f2d_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_30f2d_row0_col2" class="data row0 col2" >1.123</td>
#     </tr>
#     <tr>
#       <th id="T_30f2d_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_30f2d_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_30f2d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_30f2d_row1_col2" class="data row1 col2" >1,000.230</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import numpy as np
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
weather_df = pd.DataFrame(np.random.rand(50,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=50),
                          columns=["Tokyo","Taipei"]
                          )
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50 entries, 2024-01-01 to 2024-02-19
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tokyo   50 non-null     float64
#  1   Taipei  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
#因為索引是datetime的資料
# weather_df.loc['2024-01-10':'2024-01-30']
# weather_df.loc['2024-01']
weather_df.loc['2024']
# Out:
#                Tokyo    Taipei
# 2024-01-01  4.773188  1.674597
# 2024-01-02  0.064749  0.326315
# 2024-01-03  2.898311  3.202486
# 2024-01-04  4.712936  0.015780
# 2024-01-05  0.233212  2.870245
# 2024-01-06  4.798813  0.462849
# 2024-01-07  2.616535  4.791174
# 2024-01-08  3.528748  2.161523
# 2024-01-09  4.711394  3.045104
# 2024-01-10  3.713196  1.183787
# 2024-01-11  1.753530  2.005886
# 2024-01-12  4.967287  1.572989
# 2024-01-13  0.423455  4.614268
# 2024-01-14  4.611537  4.291892
# 2024-01-15  2.321139  4.102901
# 2024-01-16  0.774570  4.781951
# 2024-01-17  4.878044  1.249708
# 2024-01-18  2.966432  4.508483
# 2024-01-19  3.995524  4.733518
# 2024-01-20  4.887841  4.983965
# 2024-01-21  3.071262  1.423243
# 2024-01-22  1.416369  1.987686
# 2024-01-23  1.858081  3.071887
# 2024-01-24  1.821737  3.095108
# 2024-01-25  4.436531  3.915933
# 2024-01-26  2.394111  0.467434
# 2024-01-27  1.591024  2.932447
# 2024-01-28  3.313244  0.793942
# 2024-01-29  0.060126  4.144759
# 2024-01-30  2.861590  4.720362
# 2024-01-31  2.269064  3.525923
# 2024-02-01  2.079621  4.770976
# 2024-02-02  4.072680  3.901644
# 2024-02-03  3.990926  0.133634
# 2024-02-04  1.497120  3.815765
# 2024-02-05  2.369073  0.605803
# 2024-02-06  2.117649  4.496091
# 2024-02-07  0.005665  2.101556
# 2024-02-08  1.189898  3.072481
# 2024-02-09  2.481156  2.109008
# 2024-02-10  1.041282  2.644774
# 2024-02-11  4.626862  3.506766
# 2024-02-12  1.714720  0.941577
# 2024-02-13  4.375847  3.452810
# 2024-02-14  4.143964  2.194735
# 2024-02-15  0.955212  1.996284
# 2024-02-16  1.107262  1.822639
# 2024-02-17  3.792133  0.444891
# 2024-02-18  3.651657  0.202469
# 2024-02-19  4.159781  2.814273

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['Tokyo'],label='Tokyyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['Taipei'],label='Taiepi',linestyle='',marker='.')
plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()

# %%
np.random.seed(1234)
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2024-01-01", periods=10),
                          columns=["Tokyo","Taipei"]
                          )
display(weather_df)
def rain_condition(v):
    if v < 1.75:
        return "乾燥"
    elif v < 2.75:
        return "小雨"
    else:
        return "大雨"

def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None,vmin=1,vmax=5,cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s.to_excel('weather_condition.xlsx')
# Out:
#                Tokyo    Taipei
# 2024-01-01  0.957597  3.110544
# 2024-01-02  2.188639  3.926793
# 2024-01-03  3.899879  1.362963
# 2024-01-04  1.382321  4.009361
# 2024-01-05  4.790697  4.379663
# 2024-01-06  1.789086  2.504976
# 2024-01-07  3.417315  3.563510
# 2024-01-08  1.851254  2.805981
# 2024-01-09  2.515416  0.068842
# 2024-01-10  3.864133  4.413206
